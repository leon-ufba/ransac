# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
def plot_profiling_bar(file):
    plt.figure(figsize=(10, 6))
    #plt.bar(profiling['step'], profiling['square_root'], label='square_root')
    #plt.bar(profiling['step'], profiling['calculateIntersection'], label='calculateIntersection')
    #plt.bar(profiling['step'], profiling['getAngleFromModel'], label='getAngleFromModel')
    plt.bar(file['step'], file['leastSquare'], label='leastSquare')
    plt.bar(file['step'], file['coefficientOfDetermination'], label='coefficientOfDetermination')
    plt.bar(file['step'], file['inliersOutliersMemory'], label='inliersOutliersMemory')
    plt.bar(file['step'], file['inliersOutliers'], label='inliersOutliers')
    #plt.bar(profiling['step'], profiling['squareDistanceBetweenPoints'], label='squareDistanceBetweenPoints')


    plt.xticks(file['step'])
    plt.xlabel('Step')
    plt.ylabel('Valor')
    plt.title('Gráfico de Barras')
    plt.legend()


    plt.show()

# %%
def FPGAout_read(filename):
    data = []
    columns = ['step', 'model', 'bestfit', 'inliers', 'angle', 'distance']

    with open(filename, 'r') as file:
        while True:
            result = {}
            test_case = file.readline().strip()
            if not test_case:
                break
            result['step'] = int(test_case)
            result['model'] = list(map(float, file.readline()[1:-2].split(',')))
            result['bestfit'] = float(file.readline().strip())
            result['inliers'] = int(file.readline().strip())
            result['angle'] = float(file.readline().strip())
            result['distance'] = float(file.readline().strip())
            file.readline()
            data.append(result)

    return pd.DataFrame(data, columns=columns)

# %%
path = 'resultados'

# %%
padrao_arquivos = os.path.join(path, '*')  # define o padrão para listar todos os arquivos na pasta
lista_arquivos = glob.glob(padrao_arquivos)
lista_arquivos
# Out:
# ['resultados\\FPGAin.txt',
#  'resultados\\FPGAout-PC.txt',
#  'resultados\\FPGAout.txt',
#  'resultados\\FPGAout_HFP.txt',
#  'resultados\\FPGAout_O2.txt',
#  'resultados\\FPGAout_O3.txt',
#  'resultados\\Profiling.csv',
#  'resultados\\Profiling.txt',
#  'resultados\\Profiling_HFP.csv',
#  'resultados\\Profiling_HFP.txt',
#  'resultados\\Profiling_O.csv',
#  'resultados\\Profiling_O2.csv',
#  'resultados\\Profiling_O2.txt',
#  'resultados\\Profiling_O3.csv',
#  'resultados\\Profiling_O3.txt']

# %%
Profiling_HFP = pd.read_csv(lista_arquivos[8])
Profiling_O3 = pd.read_csv(lista_arquivos[13])
Profiling_HFP - Profiling_O3
# Out:
#     step  square_root  calculateIntersection  getAngleFromModel  leastSquare  \
# 0      0            0                      0                  0            0
# 1      0            0                    -66                  0        52955
# 2      0            0                      0                  0            0
# 3      0            0                    -66                  0        35700
# 4      0            0                      0                  0            0
# 5      0            0                      0                  0            0
# 6      0            0                    -66                  0       124950
# 7      0            0                      0                  0            0
# 8      0            0                    -66                  0        58225
# 9      0            0                      0                  0            0
# 10     0            0                    -66                  0        23970
# 11     0            0                      0                  0            0
# 12     0            0                      0                  0            0
# 13     0            0                      0                  0        90100
#
#     coefficientOfDetermination  inliersOutliersMemory  inliersOutliers  \
# 0                            0                  20502                0
# 1                       -25929                  19966            28140
# 2                            0                  20770                0
# 3                       -17200                  21038            16800
# 4                            0                  20502                0
# 5                            0                  20368                0
# 6                       -62350                  29480            60900
# 7                            0                  27068                0
# 8                       -28595                  18090            39900
# 9                            0                  27202                0
# 10                      -12384                  32696            40320
# 11                           0                  28944                0
# 12                           0                  27068                0
# 13                      -44720                  26800            43680
#
#     squareDistanceBetweenPoints
# 0                             0
# 1                           -90
# 2                             0
# 3                           -84
# 4                             0
# 5                             0
# 6                           -72
# 7                             0
# 8                           -78
# 9                             0
# 10                          -66
# 11                            0
# 12                            0
# 13                          -60

# %%
Profiling_O3
# Out:
#     step  square_root  calculateIntersection  getAngleFromModel  leastSquare  \
# 0      0            0                      0                  0            0
# 1      1         1175                    327             206395       570741
# 2      2            0                      0                  0            0
# 3      3         1346                    327             214572       418838
# 4      4            0                      0                  0            0
# 5      5            0                      0                  0            0
# 6      6         1175                    327             214706      1326546
# 7      7            0                      0                  0            0
# 8      8          491                    327             214295       576823
# 9      9            0                      0                  0            0
# 10    10         1346                    327             204458       279365
# 11    11            0                      0                  0            0
# 12    12            0                      0                  0            0
# 13    13            0                      0                  0       968354
#
#     coefficientOfDetermination  inliersOutliersMemory  inliersOutliers  \
# 0                            0                  88342                0
# 1                       296136                  85709           398802
# 2                            0                  89424                0
# 3                       197010                  90226           276025
# 4                            0                  88342                0
# 5                            0                  87626                0
# 6                       710460                 123574           799854
# 7                            0                 114851                0
# 8                       326172                  77939           542735
# 9                            0                 115392                0
# 10                      141255                 136901           555034
# 11                           0                 122390                0
# 12                           0                 114823                0
# 13                      509970                 113041           592637
#
#     squareDistanceBetweenPoints
# 0                             0
# 1                         44700
# 2                             0
# 3                         41694
# 4                             0
# 5                             0
# 6                         20792
# 7                             0
# 8                         35626
# 9                             0
# 10                        32368
# 11                            0
# 12                            0
# 13                        26389

# %%
plot_profiling_bar(Profiling_O3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25844\2769733699.py in <module>
# ----> 1 total = plot_profiling_bar(Profiling_O3).sum
#       2 total
#
# AttributeError: 'NoneType' object has no attribute 'sum'

# %%
plot_profiling_bar(profiling_HFP)

# %%
valor_minimo = np.min(profiling[profiling['coefficientOfDetermination'] != 0]['coefficientOfDetermination'])
valor_minimo
# Out:
# 4609508

# %%
FPGA_out_PC = FPGAout_read(lista_arquivos[1])

# %%
FPGA_out_PC
# Out:
#     step                                       model   bestfit  inliers  \
# 0      0                                 [0.0, 25.0]       inf        0
# 1      1     [1.849611391923474, -9.072286537311804]  0.153965       56
# 2      2                                 [0.0, 25.0]       inf        0
# 3      3    [0.4267146348356053, 15.852611933824722]  0.361517       28
# 4      4                                 [0.0, 25.0]       inf        0
# 5      5                                 [0.0, 25.0]       inf        0
# 6      6   [-0.7649217947693504, 34.272184980922894]  0.054745      114
# 7      7                                 [0.0, 25.0]       inf        0
# 8      8    [1.1687408622449298, 24.289339978544156]  0.133508       85
# 9      9                                 [0.0, 25.0]       inf        0
# 10    10     [1.189905659879246, -10.91871541379814]  0.158762       81
# 11    11                                 [0.0, 25.0]       inf        0
# 12    12                                 [0.0, 25.0]       inf        0
# 13    13  [0.031127251169172834, 32.254834599795615]  0.691366       19
#
#        angle    distance
# 0   0.000000   50.000000
# 1  -1.075157   18.421322
# 2  -1.075157   50.000000
# 3  -1.478479   21.436781
# 4  -1.478479   50.000000
# 5  -1.478479   50.000000
# 6  -0.825496   12.121742
# 7  -0.825496   50.000000
# 8  -1.688544    0.608056
# 9  -1.688544   50.000000
# 10 -2.560444   30.186188
# 11 -2.560444   50.000000
# 12 -2.560444   50.000000
# 13 -2.591561 -233.070198

# %%
FPGA_out_NIOS = FPGAout_read(lista_arquivos[2])

# %%
FPGA_out_NIOS
# Out:
#     step                   model   bestfit  inliers     angle   distance
# 0      0             [0.0, 25.0]       inf      153  0.000000  50.000000
# 1      1    [1.9253, -11.349117]  0.115460       67 -1.091750  18.141445
# 2      2             [0.0, 25.0]       inf      155  0.000000  50.000000
# 3      3    [0.481072, 12.98444]  0.236668       40 -0.448391  24.021948
# 4      4             [0.0, 25.0]       inf      153  0.000000  50.000000
# 5      5             [0.0, 25.0]       inf      152  0.000000  50.000000
# 6      6  [-0.770371, 33.592865]  0.029266      145  0.656412  11.000189
# 7      7             [0.0, 25.0]       inf      202  0.000000  50.000000
# 8      8   [1.203124, 23.710875]  0.116742       95 -0.877336   1.416667
# 9      9             [0.0, 25.0]       inf      203  0.000000  50.000000
# 10    10   [1.014305, -3.270336]  1.206054       91 -0.792500  27.022642
# 11    11             [0.0, 25.0]       inf      216  0.000000  50.000000
# 12    12             [0.0, 25.0]       inf      202  0.000000  50.000000
# 13    13    [0.02619, 30.954239]  0.821760      104  0.000000  50.000000
